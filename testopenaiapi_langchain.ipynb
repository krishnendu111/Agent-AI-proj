# %%
import openai

# %%
import pandas as pd

# %%
mykey="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"

# %%
openai.api_key = mykey

# %%
all_models=list(openai.models.list())

# %%
pd.DataFrame(list(all_models))
# Out:
#                                     0                      1                2  \
# 0                    (id, gpt-4-0613)  (created, 1686588896)  (object, model)
# 1                         (id, gpt-4)  (created, 1687882411)  (object, model)
# 2                 (id, gpt-3.5-turbo)  (created, 1677610602)  (object, model)
# 3                 (id, gpt-5.2-codex)  (created, 1766164985)  (object, model)
# 4    (id, gpt-4o-mini-tts-2025-12-15)  (created, 1765610837)  (object, model)
# ..                                ...                    ...              ...
# 110  (id, gpt-4o-mini-tts-2025-03-20)  (created, 1765610731)  (object, model)
# 111           (id, gpt-3.5-turbo-16k)  (created, 1683758102)  (object, model)
# 112                       (id, tts-1)  (created, 1681940951)  (object, model)
# 113                   (id, whisper-1)  (created, 1677532384)  (object, model)
# 114      (id, text-embedding-ada-002)  (created, 1671217299)  (object, model)
#
#                                3
# ...

# %%
import langchain
